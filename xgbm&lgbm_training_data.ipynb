# %%
##STEP 1

#Exploratory Data Analysis (EDA):
#1.Load the Titanic dataset using Python's pandas library.

# %%
##importing data files
##importing pandas
import pandas as pd
df1=pd.read_csv("Titanic_train.csv")
df2=pd.read_csv("Titanic_test.csv")

# %%
#2.Check for missing values.

# %%
#files are combined for analysis and again will be seperated

# %%
##CONCATING TWO FILES
df3 = pd.concat([df1,df2],ignore_index=True)
df3
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
##DATA CLEANING AND HANDLING MISSING VALUES

# %%
#REPLACEMENT OF NULL VALUES

##A. AGE CONTINOUS VARIABLE
#B. FARE CONTINOUS VARIABLE
#C. CABIN CATEGORICAL VARIABLE
#D. EMBARKED CATEGORICAL VARIABLE

# %%
df3['Age'].fillna(df3['Age'].median(), inplace=True)

# %%
df3['Age'].fillna(df3['Age'].median(), inplace=True)

# %%
df3.shape
# Out:
# (1309, 12)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
df3['Fare'].fillna(df3['Fare'].median(), inplace=True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
df3["Embarked"]
# Out:
# 0       S
# 1       C
# 2       S
# 3       S
# 4       S
#        ..
# 1304    S
# 1305    C
# 1306    S
# 1307    S
# 1308    C
# Name: Embarked, Length: 1309, dtype: object

# %%
df3["Embarked"].value_counts()
# Out:
# Embarked
# S    914
# C    270
# Q    123
# Name: count, dtype: int64

# %%
##since Embarked is a categorical varaible we are going to replace with mode

# %%
df3["Embarked"].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df3["Embarked"].fillna("S",inplace=True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
df3["Embarked"]
# Out:
# 0       S
# 1       C
# 2       S
# 3       S
# 4       S
#        ..
# 1304    S
# 1305    C
# 1306    S
# 1307    S
# 1308    C
# Name: Embarked, Length: 1309, dtype: object

# %%
#we can observe there are not any null values

# %%
df3["Cabin"].mode()
# Out:
# 0    C23 C25 C27
# Name: Cabin, dtype: object

# %%
df3["Cabin"].fillna("C23 C25 C27",inplace=True)

# %%
df3["Cabin"]
# Out:
# 0       C23 C25 C27
# 1               C85
# 2       C23 C25 C27
# 3              C123
# 4       C23 C25 C27
#            ...
# 1304    C23 C25 C27
# 1305           C105
# 1306    C23 C25 C27
# 1307    C23 C25 C27
# 1308    C23 C25 C27
# Name: Cabin, Length: 1309, dtype: object

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
#Cabin column is also categorical variable hence we replaced with mode

# %%
#3.Explore data distributions using histograms and box plots.

# %%
#PERFORMING HISTOGRAMS AND BOXPLOTS FOR NUMERICAL DATA

# %%
#CONTINOUS DATA IS PCLASS,AGE,SIBSP,PARCH,FARE

# %%
## EXPLORATORY DATA ANALYSIS
import matplotlib.pyplot as plt
#	2 a. Construct the box plot for all X variables
plt.boxplot(df3['Pclass'],vert = False)
plt.show()

plt.boxplot(df3['Age'],vert = False)
plt.show()

plt.boxplot(df3['SibSp'],vert = False)
plt.show()

# %%
##for age column we can observe there are more number of outliers
##for sibsp column from the boxplot there are only 4 data points showing as an ourtliers above the upper quartile range

# %%
plt.boxplot(df3['Parch'],vert = False)
plt.show()

plt.boxplot(df3['Fare'],vert = False)
plt.show()

# %%
#for parch column we can observe only 7 number of oultiers and the boxplot is shrinked to 0 because almost the data is 0
#for Fare column there are more number of oultiers as a view from the boxplot.

# %%
##HISTOGRAMS

# %%
#Construct the histogram for all X variables
plt.hist(df3["Pclass"])
plt.show()

# %%
df3["Pclass"].value_counts()
# Out:
# Pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
#the histogram is showing that more number of Pclass is observed from 3 (highest)

# %%
##Age
plt.hist(df3["Age"])
plt.show()

# %%
# from the histogram we can observe that above the age of 25(approx) and between the 30 are more people than compared to
# people who are having age more than 30-40 and less than 20.

# %%
##SibSp
plt.hist(df3["SibSp"])
plt.show()

# %%
df3["SibSp"].value_counts()
# Out:
# SibSp
# 0    891
# 1    319
# 2     42
# 4     22
# 3     20
# 8      9
# 5      6
# Name: count, dtype: int64

# %%
#The value of 0 is the highest repeating from the column SibSp.

# %%
##Fare
plt.hist(df3["Fare"])
plt.show()

# %%
df3["Fare"].value_counts()
# Out:
# Fare
# 8.0500     60
# 13.0000    59
# 7.7500     55
# 26.0000    50
# 7.8958     49
#            ..
# 7.7417      1
# 8.1583      1
# 8.4583      1
# 7.8000      1
# 7.7208      1
# Name: count, Length: 281, dtype: int64

# %%
#from the graph we can undertand that value from 0-50 is repeating frequently and remaining are repeating only once
# from observation of value counts the reamining values are repeating only once.

# %%
#Parch 
plt.hist(df3["Parch"])
plt.show()

# %%
df3["Parch"].value_counts()
# Out:
# Parch
# 0    1002
# 1     170
# 2     113
# 3       8
# 5       6
# 4       6
# 6       2
# 9       2
# Name: count, dtype: int64

# %%
##from the histograms we can understand that 0-2 range values are repeating more and more.
# from the value counts we can observe that the value 0 is repeating 1000 times (highest).

# %%
#4.Visualize relationships between features and survival using scatter plots and bar plots.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#let us perform scatterplots and barplots with survived column with the training data set.

# %%
#CONTINOUS DATA IS PCLASS,AGE,SIBSP,PARCH,FARE

# %%
#Construct the scatter plot with every X variable with Y.
#continous data
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#1.Pclass
plt.scatter(df1["Pclass"],df1["Survived"])
plt.xlabel("Pclass")
plt.ylabel("Survived")
plt.show()

# %%
#2.age
plt.scatter(df1["Age"],df1["Survived"])
plt.xlabel("Age")
plt.ylabel("Survived")
plt.show()

# %%
#3.SibSp
plt.scatter(df1["SibSp"],df1["Survived"])
plt.xlabel("SibSp")
plt.ylabel("Survived")
plt.show()

# %%
#4.Parch
plt.scatter(df1["Parch"],df1["Survived"])
plt.xlabel("Parch")
plt.ylabel("Survived")
plt.show()

# %%
#for Parch column the data is lying under 0 more than 1.0

# %%
#5.Fare
plt.scatter(df1["Fare"],df1["Survived"])
plt.xlabel("Fare")
plt.ylabel("Survived")
plt.show()

# %%
##BARPLOTS

# %%
#Bar Chart Analysis with categorical columns
#Categorical Columns identified are "Cabin,Embarked,Sex,Ticket"
#since name is unique we are ignoring it
#continous columns are Pclass,Parch,SibSp,Fare,Age
#passenger is also unique so we are ignoring it

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
##BAR CHART CONSTRUCTION
#OBSERVING BARPLOTS BETWEEN FEATURES AND SURVIVAL COLUMN

# %%
d1=df3.groupby("Sex")["Survived"].sum()
d1.plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
d2=df3.groupby("Pclass")["Survived"].sum()
d2.plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
d3=df3.groupby("Parch")["Survived"].sum()
d3.plot(kind='bar')
# Out:
# <Axes: xlabel='Parch'>

# %%
d4=df3.groupby("SibSp")["Survived"].sum()
d4.plot(kind='bar')
# Out:
# <Axes: xlabel='SibSp'>

# %%
d5=df3.groupby("Fare")["Survived"].sum()
d5.plot(kind='bar')
# Out:
# <Axes: xlabel='Fare'>

# %%
d6=df3.groupby("Age")["Survived"].sum()
d6.plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
d7=df3.groupby("Cabin")["Survived"].sum()
d7.plot(kind='bar')
# Out:
# <Axes: xlabel='Cabin'>

# %%
d8=df3.groupby("Ticket")["Survived"].sum()
d8.plot(kind='bar')
# Out:
# <Axes: xlabel='Ticket'>

# %%
d9=df3.groupby("Embarked")["Survived"].sum()
d9.plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
#we cannot able to clearly see through barplots so we need to conisder the facetgrid for cateogrical data inorder to observe correctly.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Create a FacetGrid for the categorical variable 'Sex'
g5 = sns.FacetGrid(df1, col="Sex")
g5.map(plt.hist, "Survived")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Create a FacetGrid for the categorical variable 'Cabin'
g5 = sns.FacetGrid(df1, col="Cabin")
g5.map(plt.hist, "Survived")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt



g5 = sns.FacetGrid(df1, col="Age")
g5.map(plt.hist, "Survived")

plt.show()

# %%
# Pair Plots

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df3.select_dtypes(include=[float, int]))
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#STEP 2

# %%
#Data Preprocessing:
#1.Impute missing values.
#2.Encode categorical variables using one-hot encoding or label encoding. 
#3.If needed you can apply more preprocessing methods on the given dataset.

# %%
#WE HAD ALREADY DONE IMPUTING OF MISSING VALUES IN THE ABOVE STEPS

# %%
##STANDARDIZATION AND LABEL ENCODING

# %%
##STANDARDISATION
##identify the numerical columns
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
# Identify numerical columns
df_num = df3[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]

df_num['Pclass'] = SS.fit_transform(df_num[['Pclass']])
df_num['Age'] = SS.fit_transform(df_num[['Age']])
df_num['SibSp'] = SS.fit_transform(df_num[['SibSp']])
df_num['Parch'] = SS.fit_transform(df_num[['Parch']])
df_num['Fare'] = SS.fit_transform(df_num[['Fare']])
df_num.head()
# Out:
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_6052\4029578686.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num['Pclass'] = SS.fit_transform(df_num[['Pclass']])
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_6052\4029578686.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_num['Age'] = SS.fit_transform(df_num[['Age']])
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_6052\4029578686.py:10: SettingWithCopyWarning:
# ...

# %%
##LABEL ENCDING
##EMBARKED AND CABIN ARE REPLACED WITH MODE VALUES
##ticket and sex are repplaced with label encoding

from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()
df_cate= df3[["Ticket","Sex","Cabin","Embarked"]]

# %%
df_cate["Cabin"] = LE.fit_transform(df_cate[["Cabin"]])

df_cate["Embarked"] = LE.fit_transform(df_cate[["Embarked"]])


df_cate["Sex"] = LE.fit_transform(df_cate[["Sex"]])
df_cate["Ticket"] = LE.fit_transform(df_cate[["Ticket"]])

df_cate.head()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Hima Chandana\AppData\Local\Temp\ipykernel_6052\3166219504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cate["Cabin"] = LE.fit_transform(df_cate[["Cabin"]])
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df3
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df3.shape
# Out:
# (1309, 12)

# %%
##CONCATINATING CATEGORICAL AND NUMERICAL COLUMNS

# %%
#Combining df_num and df_cate

# %%
df_new2=pd.concat([df_num,df_cate],axis=1)

# %%
df_new2
# Out:
#         Pclass       Age     SibSp     Parch      Fare  Ticket  Sex  Cabin  \
# 0     0.841916 -0.581628  0.481288 -0.445000 -0.503291     720    1     80
# 1    -1.546098  0.658652  0.481288 -0.445000  0.734744     816    0    106
# 2     0.841916 -0.271558 -0.479087 -0.445000 -0.490240     914    0     80
# 3    -1.546098  0.426099  0.481288 -0.445000  0.383183      65    0     70
# 4     0.841916  0.426099 -0.479087 -0.445000 -0.487824     649    1     80
# ...        ...       ...       ...       ...       ...     ...  ...    ...
# 1304  0.841916 -0.116523 -0.479087 -0.445000 -0.487824     711    1     80
# 1305 -1.546098  0.736169 -0.479087 -0.445000  1.462034     834    0     64
# 1306  0.841916  0.697411 -0.479087 -0.445000 -0.503291     872    1     80
# 1307  0.841916 -0.116523 -0.479087 -0.445000 -0.487824     579    1     80
# 1308  0.841916 -0.116523  0.481288  0.710763 -0.211184     262    1     80
#
#       Embarked
# 0            2
# 1            0
# 2            2
# ...

# %%
##COMBINING THE COLUMNS WHICH ARE HANDLED BEFORE STANDARDIZATION

# %%
##X DATA SET OBTAINED WILL BE AS FOLLOWS

# %%
df_new3=pd.concat([df_new2,df3["Survived"]],axis=1)

# %%
df_new3
# Out:
#         Pclass       Age     SibSp     Parch      Fare  Ticket  Sex  Cabin  \
# 0     0.841916 -0.581628  0.481288 -0.445000 -0.503291     720    1     80
# 1    -1.546098  0.658652  0.481288 -0.445000  0.734744     816    0    106
# 2     0.841916 -0.271558 -0.479087 -0.445000 -0.490240     914    0     80
# 3    -1.546098  0.426099  0.481288 -0.445000  0.383183      65    0     70
# 4     0.841916  0.426099 -0.479087 -0.445000 -0.487824     649    1     80
# ...        ...       ...       ...       ...       ...     ...  ...    ...
# 1304  0.841916 -0.116523 -0.479087 -0.445000 -0.487824     711    1     80
# 1305 -1.546098  0.736169 -0.479087 -0.445000  1.462034     834    0     64
# 1306  0.841916  0.697411 -0.479087 -0.445000 -0.503291     872    1     80
# 1307  0.841916 -0.116523 -0.479087 -0.445000 -0.487824     579    1     80
# 1308  0.841916 -0.116523  0.481288  0.710763 -0.211184     262    1     80
#
#       Embarked  Survived
# 0            2       0.0
# ...

# %%
df_new3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    1309 non-null   float64
#  1   Age       1309 non-null   float64
#  2   SibSp     1309 non-null   float64
#  3   Parch     1309 non-null   float64
#  4   Fare      1309 non-null   float64
#  5   Ticket    1309 non-null   int32
#  6   Sex       1309 non-null   int32
#  7   Cabin     1309 non-null   int32
#  8   Embarked  1309 non-null   int32
#  9   Survived  891 non-null    float64
# dtypes: float64(6), int32(4)
# memory usage: 81.9 KB

# %%
##CHECKING IF THRERE ARE ANY NULL VALUES
df_new3.isnull()
# Out:
#       Pclass    Age  SibSp  Parch   Fare  Ticket    Sex  Cabin  Embarked  \
# 0      False  False  False  False  False   False  False  False     False
# 1      False  False  False  False  False   False  False  False     False
# 2      False  False  False  False  False   False  False  False     False
# 3      False  False  False  False  False   False  False  False     False
# 4      False  False  False  False  False   False  False  False     False
# ...      ...    ...    ...    ...    ...     ...    ...    ...       ...
# 1304   False  False  False  False  False   False  False  False     False
# 1305   False  False  False  False  False   False  False  False     False
# 1306   False  False  False  False  False   False  False  False     False
# 1307   False  False  False  False  False   False  False  False     False
# 1308   False  False  False  False  False   False  False  False     False
#
#       Survived
# 0        False
# 1        False
# 2        False
# 3        False
# ...

# %%
#Analyze any patterns or correlations observed in the data.

# %%
df_new3.corr()
# Out:
#             Pclass       Age     SibSp     Parch      Fare    Ticket  \
# Pclass    1.000000 -0.377908  0.060832  0.018322 -0.558683  0.309695
# Age      -0.377908  1.000000 -0.189972 -0.125851  0.178182 -0.087720
# SibSp     0.060832 -0.189972  1.000000  0.373587  0.160349  0.063921
# Parch     0.018322 -0.125851  0.373587  1.000000  0.221635  0.053389
# Fare     -0.558683  0.178182  0.160349  0.221635  1.000000 -0.014902
# Ticket    0.309695 -0.087720  0.063921  0.053389 -0.014902  1.000000
# Sex       0.124617  0.053663 -0.109609 -0.213125 -0.185681  0.024725
# Cabin    -0.053937 -0.021154  0.001357  0.006535 -0.034991 -0.032243
# Embarked  0.185479 -0.063424  0.065567  0.044772 -0.238131  0.031453
# Survived -0.338481 -0.064910 -0.035322  0.081629  0.257307 -0.166734
#
#                Sex     Cabin  Embarked  Survived
# Pclass    0.124617 -0.053937  0.185479 -0.338481
# Age       0.053663 -0.021154 -0.063424 -0.064910
# SibSp    -0.109609  0.001357  0.065567 -0.035322
# ...

# %%
#Building Predictive Models:
#1.Split the preprocessed dataset into training and testing sets.
#2.Choose appropriate evaluation metrics (e.g., accuracy, precision, recall, F1-score) for model evaluation.
#3.Build predictive models using LightGBM and XGBoost algorithms.
#4.Train the models on the training set and evaluate their performance on the testing set.
#5.Use techniques like cross-validation and hyperparameter tuning to optimize model performance.

# %%
##SEPERATING DATA FOR X AND Y that is Training Data and Testing data and declaring target variable

# %%
Y=df3["Survived"]

# %%
Y
# Out:
# 0       0.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       0.0
#        ...
# 1304    NaN
# 1305    NaN
# 1306    NaN
# 1307    NaN
# 1308    NaN
# Name: Survived, Length: 1309, dtype: float64

# %%
X = df_new3.iloc[:,0:9]
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    1309 non-null   float64
#  1   Age       1309 non-null   float64
#  2   SibSp     1309 non-null   float64
#  3   Parch     1309 non-null   float64
#  4   Fare      1309 non-null   float64
#  5   Ticket    1309 non-null   int32
#  6   Sex       1309 non-null   int32
#  7   Cabin     1309 non-null   int32
#  8   Embarked  1309 non-null   int32
# dtypes: float64(5), int32(4)
# memory usage: 71.7 KB

# %%
df3["Survived"].value_counts()
# Out:
# Survived
# 0.0    549
# 1.0    342
# Name: count, dtype: int64

# %%
##SEPERATING TRAINING DATA
training_data  = df_new3[(df_new3["Survived"] == 0) | (df_new3["Survived"] == 1)]

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    891 non-null    float64
#  1   Age       891 non-null    float64
#  2   SibSp     891 non-null    float64
#  3   Parch     891 non-null    float64
#  4   Fare      891 non-null    float64
#  5   Ticket    891 non-null    int32
#  6   Sex       891 non-null    int32
#  7   Cabin     891 non-null    int32
#  8   Embarked  891 non-null    int32
#  9   Survived  891 non-null    float64
# dtypes: float64(6), int32(4)
# memory usage: 62.6 KB

# %%
X2=training_data.iloc[:,0:9]

# %%
X2
# Out:
#        Pclass       Age     SibSp     Parch      Fare  Ticket  Sex  Cabin  \
# 0    0.841916 -0.581628  0.481288 -0.445000 -0.503291     720    1     80
# 1   -1.546098  0.658652  0.481288 -0.445000  0.734744     816    0    106
# 2    0.841916 -0.271558 -0.479087 -0.445000 -0.490240     914    0     80
# 3   -1.546098  0.426099  0.481288 -0.445000  0.383183      65    0     70
# 4    0.841916  0.426099 -0.479087 -0.445000 -0.487824     649    1     80
# ..        ...       ...       ...       ...       ...     ...  ...    ...
# 886 -0.352091 -0.194041 -0.479087 -0.445000 -0.392119     130    1     80
# 887 -1.546098 -0.814181 -0.479087 -0.445000 -0.063437      18    0     40
# 888  0.841916 -0.116523  0.481288  1.866526 -0.190076     923    0     80
# 889 -1.546098 -0.271558 -0.479087 -0.445000 -0.063437      11    1     77
# 890  0.841916  0.193547 -0.479087 -0.445000 -0.493624     642    1     80
#
#      Embarked
# 0           2
# 1           0
# 2           2
# 3           2
# ...

# %%
Y=training_data["Survived"]

# %%
Y
# Out:
# 0      0.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      0.0
#       ...
# 886    0.0
# 887    1.0
# 888    0.0
# 889    1.0
# 890    0.0
# Name: Survived, Length: 891, dtype: float64

# %%
# Data partition
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X2,Y,test_size=0.3,random_state=10)

# %%
##MODEL FITTING

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
from xgboost import XGBRegressor

model = XGBRegressor()
model.fit(X_train,Y_train)
Y_pred_train = model.predict(X_train)
Y_pred_test  = model.predict(X_test)
from sklearn.metrics import mean_squared_error
train_rmse = mean_squared_error(Y_train,Y_pred_train,squared=False)
print("Training Error:",train_rmse)
test_rmse = mean_squared_error(Y_test,Y_pred_test,squared=False)
print("Test Error:",test_rmse)
# Out:
# Training Error: 0.03704843611047806
# Test Error: 0.3763323287784972

# %%
#CROSS VALIDATION

# %%
from xgboost import XGBRegressor

training_err = []
test_err = []

for i in range(1,101):
    X_train,X_test,Y_train,Y_test = train_test_split(X2,Y, test_size=0.25,random_state=i)
    model = XGBRegressor(learning_rate=0.5,gamma=140,alpha=0.5,n_estimators=100)
    model.fit(X_train,Y_train)
    Y_pred_train = model.predict(X_train)
    Y_pred_test  = model.predict(X_test)
    training_err.append(mean_squared_error(Y_train,Y_pred_train,squared=False))
    test_err.append(mean_squared_error(Y_test,Y_pred_test,squared=False))

import numpy as np
print("Cross validation - Training error:" ,np.mean(training_err).round(2))
print("Cross validation - Test error:" ,np.mean(test_err).round(2))
print("XGBBoost -variance :" ,(np.mean(test_err)-np.mean(training_err)).round(2))
# Out:
# Cross validation - Training error: 0.49
# Cross validation - Test error: 0.49
# XGBBoost -variance : 0.0

# %%
from xgboost import XGBRegressor

training_err = []
test_err = []

for i in range(1,101):
    X_train,X_test,Y_train,Y_test = train_test_split(X2,Y, test_size=0.25,random_state=i)
    model = XGBRegressor(learning_rate=0.6,gamma=160,alpha=0.5,n_estimators=150)
    model.fit(X_train,Y_train)
    Y_pred_train = model.predict(X_train)
    Y_pred_test  = model.predict(X_test)
    training_err.append(mean_squared_error(Y_train,Y_pred_train,squared=False))
    test_err.append(mean_squared_error(Y_test,Y_pred_test,squared=False))

import numpy as np
print("Cross validation - Training error:" ,np.mean(training_err).round(2))
print("Cross validation - Test error:" ,np.mean(test_err).round(2))
print("XGBBoost -variance :" ,(np.mean(test_err)-np.mean(training_err)).round(2))
# Out:
# Cross validation - Training error: 0.49
# Cross validation - Test error: 0.49
# XGBBoost -variance : 0.0

# %%
from xgboost import XGBRegressor

training_err = []
test_err = []

for i in range(1,101):
    X_train,X_test,Y_train,Y_test = train_test_split(X2,Y, test_size=0.25,random_state=56)
    model = XGBRegressor(learning_rate=0.4,gamma=120,alpha=0.5,n_estimators=200)
    model.fit(X_train,Y_train)
    Y_pred_train = model.predict(X_train)
    Y_pred_test  = model.predict(X_test)
    training_err.append(mean_squared_error(Y_train,Y_pred_train,squared=False))
    test_err.append(mean_squared_error(Y_test,Y_pred_test,squared=False))

import numpy as np
print("Cross validation - Training error:" ,np.mean(training_err).round(2))
print("Cross validation - Test error:" ,np.mean(test_err).round(2))
print("XGBBoost -variance :" ,(np.mean(training_err)-np.mean(test_err)).round(2))
# Out:
# Cross validation - Training error: 0.49
# Cross validation - Test error: 0.48
# XGBBoost -variance : 0.01

# %%
from xgboost import XGBRegressor

training_err = []
test_err = []

for i in range(1,101):
    X_train,X_test,Y_train,Y_test = train_test_split(X2,Y, test_size=0.3,random_state=64)
    model = XGBRegressor(learning_rate=0.4,gamma=120,alpha=0.5,n_estimators=200)
    model.fit(X_train,Y_train)
    Y_pred_train = model.predict(X_train)
    Y_pred_test  = model.predict(X_test)
    training_err.append(mean_squared_error(Y_train,Y_pred_train,squared=False))
    test_err.append(mean_squared_error(Y_test,Y_pred_test,squared=False))

import numpy as np
print("Cross validation - Training error:" ,np.mean(training_err).round(2))
print("Cross validation - Test error:" ,np.mean(test_err).round(2))
print("XGBBoost -variance :" ,(np.mean(training_err)-np.mean(test_err)).round(2))
# Out:
# Cross validation - Training error: 0.49
# Cross validation - Test error: 0.49
# XGBBoost -variance : -0.0

# %%
from xgboost import XGBRegressor

training_err = []
test_err = []

for i in range(1,101):
    X_train,X_test,Y_train,Y_test = train_test_split(X2,Y, test_size=0.4,random_state=i)
    model = XGBRegressor(learning_rate=0.4,gamma=100,alpha=0.5,n_estimators=100)
    model.fit(X_train,Y_train)
    Y_pred_train = model.predict(X_train)
    Y_pred_test  = model.predict(X_test)
    training_err.append(mean_squared_error(Y_train,Y_pred_train,squared=False))
    test_err.append(mean_squared_error(Y_test,Y_pred_test,squared=False))

import numpy as np
print("Cross validation - Training error:" ,np.mean(training_err).round(2))
print("Cross validation - Test error:" ,np.mean(test_err).round(2))
print("XGBBoost -variance :" ,(np.mean(training_err)-np.mean(test_err)).round(2))
# Out:
# Cross validation - Training error: 0.49
# Cross validation - Test error: 0.49
# XGBBoost -variance : -0.0

# %%
from xgboost import XGBRegressor

training_err = []
test_err = []

for i in range(1,101):
    X_train,X_test,Y_train,Y_test = train_test_split(X2,Y, test_size=0.3,random_state=i)
    model = XGBRegressor(learning_rate=0.3,gamma=120,alpha=0.4,n_estimators=250)
    model.fit(X_train,Y_train)
    Y_pred_train = model.predict(X_train)
    Y_pred_test  = model.predict(X_test)
    training_err.append(mean_squared_error(Y_train,Y_pred_train,squared=False))
    test_err.append(mean_squared_error(Y_test,Y_pred_test,squared=False))

import numpy as np
print("Cross validation - Training error:" ,np.mean(training_err).round(2))
print("Cross validation - Test error:" ,np.mean(test_err).round(2))
print("XGBBoost -variance :" ,(np.mean(training_err)-np.mean(test_err)).round(2))
# Out:
# Cross validation - Training error: 0.49
# Cross validation - Test error: 0.49
# XGBBoost -variance : 0.0

# %%
from xgboost import XGBRegressor

training_err = []
test_err = []

for i in range(1,101):
    X_train,X_test,Y_train,Y_test = train_test_split(X2,Y, test_size=0.3,random_state=i)
    model = XGBRegressor(learning_rate=0.0,gamma=100,n_estimators=100)
    model.fit(X_train,Y_train)
    Y_pred_train = model.predict(X_train)
    Y_pred_test  = model.predict(X_test)
    training_err.append(mean_squared_error(Y_train,Y_pred_train,squared=False))
    test_err.append(mean_squared_error(Y_test,Y_pred_test,squared=False))

import numpy as np
print("Cross validation - Training error:" ,np.mean(training_err).round(2))
print("Cross validation - Test error:" ,np.mean(test_err).round(2))
print("XGBBoost -variance :" ,(np.mean(training_err)-np.mean(test_err)).round(2))
# Out:
# Cross validation - Training error: 0.49
# Cross validation - Test error: 0.49
# XGBBoost -variance : 0.0

# %%
#=============================================================================

from sklearn.model_selection import GridSearchCV

param_grid = {
  'learning_rate': [0.0, 0.5, 1.0],
  'gamma': [100,120,140],
  'n_estimators': [100,200,300]
}

# Create the grid search object
model = XGBRegressor()
grid_search = GridSearchCV(model, param_grid, cv=5)

# Fit the grid search object to the data
grid_search.fit(X_train, Y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Print the best hyperparameters
print("Best hyperparameters:", best_params)

#=============================================================================
# Out:
# Best hyperparameters: {'gamma': 100, 'learning_rate': 0.0, 'n_estimators': 100}

# %%
##RESULTS

#TRAINING ERROR - 0.49 
#TESTING ERROR - 0.49

# %%
#Based on the nature of the error metric and the problem's context, 
#a machine learning model with training and testing errors of approximately 0.5 may indicate various problems.

# %%
#The model's performance is essentially identical to that of a random guess.
#Binary Classification: The model may be guessing the classes at random if the error is 0.5.
#Indicators: In a binary classification task, training and testing errors are around 0.5.
#Solution: Verify the preprocessing stages of the data, make sure the model is appropriately trained, 
#and think about utilizing alternative features or models.
#Bad Choice of Features:
#It's possible that the training features weren't instructive or pertinent to the goal variable.
#High testing and training mistake rates are indicators.

# %%
##we can understand model is under fitting and also showing variance is 0.0

# %%
# EVALUATION METRICS & PERFORMANCE MODEL OBSERVATION ON Training DATA.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# %%
import xgboost as xgb
dtrain = xgb.DMatrix(X_train, label=Y_train)
dtest = xgb.DMatrix(X_test, label=Y_test)

# %%
params = {
    'objective': 'binary:logistic',  # Use 'multi:softmax' for multi-class classification
    'max_depth': 6,
    'learning_rate': 0.1,
    'n_estimators': 100,
    'eval_metric': 'logloss'  # Use 'mlogloss' for multi-class classification
}

# %%
bst = xgb.train(params, dtrain, num_boost_round=100, evals=[(dtest, 'test')], early_stopping_rounds=10)
# Out:
# [0]	test-logloss:0.63515
# [1]	test-logloss:0.60088
# [2]	test-logloss:0.57307
# [3]	test-logloss:0.54983
# [4]	test-logloss:0.53082
# [5]	test-logloss:0.51477
# [6]	test-logloss:0.50341
# [7]	test-logloss:0.49310
# [8]	test-logloss:0.48584
# [9]	test-logloss:0.47883
# [10]	test-logloss:0.47189
# [11]	test-logloss:0.46556
# [12]	test-logloss:0.46172
# [13]	test-logloss:0.45957
# [14]	test-logloss:0.45531
# [15]	test-logloss:0.45214
# [16]	test-logloss:0.44849
# [17]	test-logloss:0.44676
# [18]	test-logloss:0.44439
# [19]	test-logloss:0.44301
# [20]	test-logloss:0.44275
# [21]	test-logloss:0.44105
# [22]	test-logloss:0.43994
# [23]	test-logloss:0.43876
# [24]	test-logloss:0.43770
# [25]	test-logloss:0.43712
# [26]	test-logloss:0.43671
# [27]	test-logloss:0.43643
# [28]	test-logloss:0.43717
# [29]	test-logloss:0.43651
# [30]	test-logloss:0.43564
# [31]	test-logloss:0.43563
# [32]	test-logloss:0.43591
# [33]	test-logloss:0.43587
# [34]	test-logloss:0.43573
# [35]	test-logloss:0.43510
# ...

# %%
y_pred_prob = bst.predict(dtest)
# For binary classification, convert probabilities to class labels
y_pred = [1 if pred > 0.5 else 0 for pred in y_pred_prob]

# %%
conf_matrix = confusion_matrix(Y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[145  14]
#  [ 30  79]]

# %%
accuracy = accuracy_score(Y_test, y_pred)
class_report = classification_report(Y_test, y_pred)

print(f'Accuracy: {accuracy}')

print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.835820895522388
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.91      0.87       159
#          1.0       0.85      0.72      0.78       109
#
#     accuracy                           0.84       268
#    macro avg       0.84      0.82      0.83       268
# weighted avg       0.84      0.84      0.83       268

# %%
##LGBM

# %%
##IMPLEMENTING LGBM ON TRAINING DATA SET.

# %%
pip install lightgbm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing required libraries

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
#splitting the data train and test data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X2, Y, test_size=0.2, random_state=42)

# %%
#Convert the training and testing sets into LightGBM's Dataset format.

# %%
train_data = lgb.Dataset(X_train, label=Y_train)
test_data = lgb.Dataset(X_test, label=Y_test, reference=train_data)

# %%
params = {
    'objective': 'binary',  # or 'multiclass' for multi-class classification
    'metric': 'binary_logloss',  # or 'multi_logloss' for multi-class classification
    'boosting': 'gbdt',  # Gradient Boosting Decision Tree
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9
}

# %%
model = lgb.train(params, train_data, valid_sets=[train_data, test_data], num_boost_round=100)
# Out:
# [LightGBM] [Info] Number of positive: 268, number of negative: 444
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000147 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 481
# [LightGBM] [Info] Number of data points in the train set: 712, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.376404 -> initscore=-0.504838
# [LightGBM] [Info] Start training from score -0.504838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
y_pred = model.predict(X_test, num_iteration=model.best_iteration)
# For binary classification, convert probabilities to class labels
y_pred = [1 if pred > 0.5 else 0 for pred in y_pred]

# %%
accuracy = accuracy_score(Y_test, y_pred)
conf_matrix = confusion_matrix(Y_test, y_pred)

print(f'Accuracy: {accuracy}')
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Accuracy: 0.8044692737430168
# Confusion Matrix:
# [[92 13]
#  [22 52]]

# %%
class_report = classification_report(Y_test, y_pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.88      0.84       105
#          1.0       0.80      0.70      0.75        74
#
#     accuracy                           0.80       179
#    macro avg       0.80      0.79      0.79       179
# weighted avg       0.80      0.80      0.80       179

# %%
##CODE FOR IMPLEMENTATION OF TRAIN AND TEST ERRORS FOR LGBM.

# %%
pip install lightgbm scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X2, Y, test_size=0.2, random_state=42)

# %%
# Initialize the LightGBM classifier
lgbm = lgb.LGBMClassifier(num_leaves=31, learning_rate=0.05, n_estimators=100)

# Train the model
lgbm.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Number of positive: 268, number of negative: 444
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000218 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 481
# [LightGBM] [Info] Number of data points in the train set: 712, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.376404 -> initscore=-0.504838
# [LightGBM] [Info] Start training from score -0.504838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
# Predict on the training data
y_train_pred = lgbm.predict(X_train)

# Predict on the testing data
y_test_pred = lgbm.predict(X_test)

# %%
#TRAIN METRICS

# %%
# Calculate accuracy
train_accuracy = accuracy_score(y_train, y_train_pred)


# Calculate errors
train_error = 1 - train_accuracy


# Print the results
print(f'Training Accuracy: {train_accuracy}')
print(f'Training Error: {train_error}')



train_conf_matrix = confusion_matrix(y_train, y_train_pred)

train_class_report = classification_report(y_train, y_train_pred)


print('Training Confusion Matrix:')
print(train_conf_matrix)

print('Training Classification Report:')
print(train_class_report)
# Out:
# Training Accuracy: 0.9410112359550562
# Training Error: 0.0589887640449438
# Training Confusion Matrix:
# [[433  11]
#  [ 31 237]]
# Training Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.98      0.95       444
#          1.0       0.96      0.88      0.92       268
#
#     accuracy                           0.94       712
#    macro avg       0.94      0.93      0.94       712
# weighted avg       0.94      0.94      0.94       712

# %%
#TEST METRICS

# %%
test_accuracy = accuracy_score(y_test, y_test_pred)

test_error = 1 - test_accuracy

print(f'Testing Accuracy: {test_accuracy}')
print(f'Testing Error: {test_error}')

test_conf_matrix = confusion_matrix(y_test, y_test_pred)

test_class_report = classification_report(y_test, y_test_pred)


print('Testing Confusion Matrix:')
print(test_conf_matrix)


print('Testing Classification Report:')
print(test_class_report)
# Out:
# Testing Accuracy: 0.8156424581005587
# Testing Error: 0.1843575418994413
# Testing Confusion Matrix:
# [[93 12]
#  [21 53]]
# Testing Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.89      0.85       105
#          1.0       0.82      0.72      0.76        74
#
#     accuracy                           0.82       179
#    macro avg       0.82      0.80      0.81       179
# weighted avg       0.82      0.82      0.81       179

# %%
##OBSERVING BEST PARAMETERS FOR LGBM.

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


# Split the data
X_train, X_test, y_train, y_test = train_test_split(X2, Y, test_size=0.2, random_state=42)

# Initialize LightGBM model
model = lgb.LGBMClassifier()

# Define the parameter grid
param_grid = {
    'num_leaves': [31, 50, 70],
    'learning_rate': [0.1, 0.01, 0.001],
    'n_estimators': [100, 200, 500],
    'boosting_type': ['gbdt', 'dart', 'goss']
}

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, scoring='accuracy', verbose=2, n_jobs=-1)

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best parameters found: ", best_params)

# Predict on test data with the best model
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Number of positive: 268, number of negative: 444
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000716 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 481
# [LightGBM] [Info] Number of data points in the train set: 712, number of used features: 9
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.376404 -> initscore=-0.504838
# ...

# %%
##CROSS VALIDATION RESULTS FROM LGBM

# %%
# {'boosting_type': 'goss', 'learning_rate': 0.01, 'n_estimators': 500, 'num_leaves': 31}


#Accuracy: 0.7988826815642458
#Confusion Matrix:
#[[91 14]
# [22 52]]
#Classification Report:
 #             precision    recall  f1-score   support
#
#         0.0       0.81      0.87      0.83       105
#         1.0       0.79      0.70      0.74        74

#    accuracy                           0.80       179
#   macro avg       0.80      0.78      0.79       179
## weighted avg       0.80      0.80      0.80       179
